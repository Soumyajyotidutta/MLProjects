# %%
# %%capture
! pip install transformers

# %%
import torch
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tokenized_text = "Strawberry acai is a good drink".split()
print(tokenized_text)
# Out:
# ['Strawberry', 'acai', 'is', 'a', 'good', 'drink']

# %%
from transformers import BertTokenizer

# %%
# %%capture
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")

# %%
tokenizer("We are using transformers")
# Out:
# {'input_ids': [101, 1284, 1132, 1606, 11303, 1468, 102], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
tokenizer.save_pretrained("/content/drive/MyDrive/Transformers")
# Out:
# ('/content/drive/MyDrive/Transformers/tokenizer_config.json',
#  '/content/drive/MyDrive/Transformers/special_tokens_map.json',
#  '/content/drive/MyDrive/Transformers/vocab.txt',
#  '/content/drive/MyDrive/Transformers/added_tokens.json')
